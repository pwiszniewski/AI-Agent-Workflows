# %% [markdown]
# ## first agent

# %%
# from agents import Agent, Runner
# from dotenv import load_dotenv

# load_dotenv()

# instructions = """
# You are a research planning assistant.

# **TASK INSTRUCTIONS**
# - You will be given a research topic.
# - Your task is to provide a plan on how to research this topic.
# - Output 5 concise tasks (5 words or less) to your plan.
# """

# agent = Agent(
#     name="Research Planner", 
#     instructions=instructions,
#     )

# input = "learn about AI agents"

# result = Runner.run_sync(
#     agent, 
#     input=input,
#     )

# print(result.final_output)

# %%
# from agents import Agent, Runner
# from dotenv import load_dotenv
# import asyncio

# load_dotenv()

# instructions = """
# You are a research planning assistant.

# **TASK INSTRUCTIONS**
# - You will be given a research topic.
# - Your task is to provide a plan on how to research this topic.
# - Output 5 concise tasks (5 words or less) to your plan.
# """

# agent = Agent(
#     name="Research Planner",
#     instructions=instructions,
# )

# async def main():
#     result = await Runner.run(
#         agent,
#         input="learn about AI agents",
#     )
#     print(result.final_output)

# await main()

# %%
# import os
# from dotenv import load_dotenv
# from openai import AsyncOpenAI

# instructions = """
# You are a research planning assistant.

# **TASK INSTRUCTIONS**
# - You will be given a research topic.
# - Your task is to provide a plan on how to research this topic.
# - Output 5 concise tasks (5 words or less) to your plan.
# """

# from agents import (
#     Agent,
#     Runner,
#     OpenAIChatCompletionsModel,
# )

# load_dotenv()
# print(os.getenv("GEMINI_API_KEY"))
# client = AsyncOpenAI(
#     api_key=os.getenv("GEMINI_API_KEY"),
#     base_url="https://generativelanguage.googleapis.com/v1beta/openai/",
# )

# agent = Agent(
#     name="Research Planner",
#     instructions=instructions,
#     model=OpenAIChatCompletionsModel(
#         model="gemini-3.5-flash",
#         # model="gemini-2.5-pro",
#         openai_client=client,
#     ),
# )

# result = await Runner.run(
#     agent,
#     input="learn about AI agents",
# )

# print(result.final_output)

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent.parent))

from utils import ask_agent

plan = await ask_agent(
    prompt="learn about AI agents",
    instructions="Output exactly 5 concise research tasks."
)

print(plan)
# Out:
# OPENAI_API_KEY is not set, skipping trace export
# 1. **Define the core architecture of an AI agent**, focusing on how LLMs integrate with planning, memory (short-term/long-term), and tool usage.
#
# 2. **Study key agentic design patterns**, specifically the ReAct (Reasoning and Acting) framework, reflection loops, and planning strategies.
#
# 3. **Compare leading agent development frameworks**, including LangChain/LangGraph, CrewAI, and Microsoft AutoGen.
#
# 4. **Analyze multi-agent systems** to understand how independent agents collaborate, communicate, and divide labor to solve complex workflows.
#
# 5. **Investigate major challenges in agent deployment**, such as infinite loop prevention, security vulnerabilities (e.g., prompt injection), and evaluation methodologies.
