# %% [markdown]
# ## first agent

# %%
from agents import Agent, Runner
from dotenv import load_dotenv

load_dotenv()

instructions = """
You are a research planning assistant.

**TASK INSTRUCTIONS**
- You will be given a research topic.
- Your task is to provide a plan on how to research this topic.
- Output 5 concise tasks (5 words or less) to your plan.
"""

agent = Agent(
    name="Research Planner", 
    instructions=instructions,
    )

input = "learn about AI agents"

result = Runner.run_sync(
    agent, 
    input=input,
    )

print(result.final_output)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 22
#      18     )
#      19
#      20 input = "learn about AI agents"
#      21
# ---> 22 result = Runner.run_sync(
#      23     agent,
#      24     input=input,
#      25     )
#
# File c:\Users\user\Documents\LLMs\AI-Agent-Workflows\.venv\Lib\site-packages\agents\run.py:351, in Runner.run_sync(cls, starting_agent, input, context, max_turns, hooks, run_config, error_handlers, previous_response_id, auto_previous_response_id, conversation_id, session)
#     299 """
#     300 Run a workflow synchronously, starting at the given agent.
#     301
#    (...)    347     type of the output.
#     348 """
#     350 runner = DEFAULT_AGENT_RUNNER
# --> 351 return runner.run_sync(
#     352     starting_agent,
#     353     input,
#     354     context=context,
#     355     max_turns=max_turns,
#     356     hooks=hooks,
#     357     run_config=run_config,
#     358     error_handlers=error_handlers,
#     359     previous_response_id=previous_response_id,
#     360     conversation_id=conversation_id,
#     361     session=session,
#     362     auto_previous_response_id=auto_previous_response_id,
#     363 )
#
# File c:\Users\user\Documents\LLMs\AI-Agent-Workflows\.venv\Lib\site-packages\agents\run.py:1599, in AgentRunner.run_sync(self, starting_agent, input, **kwargs)
#    1593     already_running_loop = None
#    1595 if already_running_loop is not None:
#    1596     # This method is only expected to run when no loop is already active.
#    1597     # (Each thread has its own default loop; concurrent sync runs should happen on
#    1598     # different threads. In a single thread use the async API to interleave work.)
# -> 1599     raise RuntimeError(
#    1600         "AgentRunner.run_sync() cannot be called when an event loop is already running."
#    1601     )
#    1603 policy = asyncio.get_event_loop_policy()
#    1604 with warnings.catch_warnings():
#
# RuntimeError: AgentRunner.run_sync() cannot be called when an event loop is already running.

# %%
from agents import Agent, Runner
from dotenv import load_dotenv
import asyncio

load_dotenv()

instructions = """
You are a research planning assistant.

**TASK INSTRUCTIONS**
- You will be given a research topic.
- Your task is to provide a plan on how to research this topic.
- Output 5 concise tasks (5 words or less) to your plan.
"""

agent = Agent(
    name="Research Planner",
    instructions=instructions,
)

async def main():
    result = await Runner.run(
        agent,
        input="learn about AI agents",
    )
    print(result.final_output)

await main()
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[2], line 28
#      24         input="learn about AI agents",
#      25     )
#      26     print(result.final_output)
#      27
# ---> 28 await main()
#
# Cell In[2], line 22, in main()
#      21 async def main():
# ---> 22     result = await Runner.run(
#      23         agent,
#      24         input="learn about AI agents",
#      25     )
#
# File c:\Users\user\Documents\LLMs\AI-Agent-Workflows\.venv\Lib\site-packages\agents\run.py:269, in Runner.run(cls, starting_agent, input, context, max_turns, hooks, run_config, error_handlers, previous_response_id, auto_previous_response_id, conversation_id, session)
#     215 """
#     216 Run a workflow starting at the given agent.
#     217
#    (...)    265     type of the output.
#     266 """
#     268 runner = DEFAULT_AGENT_RUNNER
# --> 269 return await runner.run(
#     270     starting_agent,
#     271     input,
#     272     context=context,
#     273     max_turns=max_turns,
#     274     hooks=hooks,
#     275     run_config=run_config,
#     276     error_handlers=error_handlers,
#     277     previous_response_id=previous_response_id,
#     278     auto_previous_response_id=auto_previous_response_id,
#     279     conversation_id=conversation_id,
#     280     session=session,
#     281 )
#
# File c:\Users\user\Documents\LLMs\AI-Agent-Workflows\.venv\Lib\site-packages\agents\run.py:1249, in AgentRunner.run(self, starting_agent, input, **kwargs)
#    1247         raise
#    1248 else:
# -> 1249     turn_result = await model_task
#    1251 input_guardrail_results.extend(sequential_results)
#    1252 input_guardrail_results.extend(parallel_results)
#
# File c:\Users\user\Documents\LLMs\AI-Agent-Workflows\.venv\Lib\site-packages\agents\run_internal\run_loop.py:1770, in run_single_turn(bindings, all_tools, original_input, generated_items, hooks, context_wrapper, run_config, should_run_agent_start_hooks, tool_use_tracker, server_conversation_tracker, session, session_items_to_rewind, reasoning_item_id_policy, prompt_cache_key_resolver, error_handlers)
#    1767 else:
#    1768     input = _prepare_turn_input_items(original_input, generated_items, reasoning_item_id_policy)
# -> 1770 new_response = await get_new_response(
#    1771     bindings,
#    1772     system_prompt,
#    1773     input,
#    1774     output_schema,
#    1775     all_tools,
#    1776     handoffs,
#    1777     hooks,
#    1778     context_wrapper,
#    1779     run_config,
#    1780     tool_use_tracker,
#    1781     server_conversation_tracker,
#    1782     prompt_config,
#    1783     session=session,
#    1784     session_items_to_rewind=session_items_to_rewind,
#    1785     prompt_cache_key_resolver=prompt_cache_key_resolver,
#    1786 )
#    1788 return await get_single_step_result_from_response(
#    1789     bindings=bindings,
#    1790     original_input=original_input,
#    (...)   1801     server_manages_conversation=server_conversation_tracker is not None,
#    1802 )
#
# File c:\Users\user\Documents\LLMs\AI-Agent-Workflows\.venv\Lib\site-packages\agents\run_internal\run_loop.py:1835, in get_new_response(bindings, system_prompt, input, output_schema, all_tools, handoffs, hooks, context_wrapper, run_config, tool_use_tracker, server_conversation_tracker, prompt_config, session, session_items_to_rewind, prompt_cache_key_resolver)
#    1832 if isinstance(filtered.input, list):
#    1833     filtered.input = deduplicate_input_items_preferring_latest(filtered.input)
# -> 1835 model = get_model(execution_agent, run_config)
#    1836 tool_use_tracker.record_model(model)
#    1837 model_settings = get_model_settings(execution_agent, run_config)
#
# File c:\Users\user\Documents\LLMs\AI-Agent-Workflows\.venv\Lib\site-packages\agents\run_internal\turn_preparation.py:135, in get_model(agent, run_config)
#     132 elif isinstance(agent.model, Model):
#     133     return agent.model
# --> 135 return run_config.model_provider.get_model(agent.model)
#
# File c:\Users\user\Documents\LLMs\AI-Agent-Workflows\.venv\Lib\site-packages\agents\models\multi_provider.py:237, in MultiProvider.get_model(self, model_name)
#     234 # Bare model names are always delegated directly to the OpenAI provider. That provider can
#     235 # still point at an OpenAI-compatible endpoint via ``base_url``.
#     236 if model_name is None:
# --> 237     return self.openai_provider.get_model(None)
#     239 prefix, stripped_model_name = self._get_prefix_and_model_name(model_name)
#     240 if prefix is None:
#
# File c:\Users\user\Documents\LLMs\AI-Agent-Workflows\.venv\Lib\site-packages\agents\models\openai_provider.py:231, in OpenAIProvider.get_model(self, model_name)
#     229     if loop_cache is not None and (cached_model := loop_cache.get(cache_key)):
#     230         return cached_model
# --> 231 client = self._get_client()
#     232 model: Model
#     234 if not self._use_responses:
#
# File c:\Users\user\Documents\LLMs\AI-Agent-Workflows\.venv\Lib\site-packages\agents\models\openai_provider.py:134, in OpenAIProvider._get_client(self)
#     132 def _get_client(self) -> AsyncOpenAI:
#     133     if self._client is None:
# --> 134         self._client = _openai_shared.get_default_openai_client() or AsyncOpenAI(
#     135             api_key=self._stored_api_key or _openai_shared.get_default_openai_key(),
#     136             base_url=self._stored_base_url or os.getenv("OPENAI_BASE_URL"),
#     137             websocket_base_url=(
#     138                 self._stored_websocket_base_url or os.getenv("OPENAI_WEBSOCKET_BASE_URL")
#     139             ),
#     140             organization=self._stored_organization,
#     141             project=self._stored_project,
#     142             http_client=shared_http_client(),
#     143         )
#     145     return self._client
#
# File c:\Users\user\Documents\LLMs\AI-Agent-Workflows\.venv\Lib\site-packages\openai\_client.py:826, in AsyncOpenAI.__init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, provider, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     816 self.admin_api_key = admin_api_key if provider_runtime is None else None
#     818 if (
#     819     provider_runtime is None
#     820     and _enforce_credentials
#    (...)    824     and self.admin_api_key is None
#     825 ):
# --> 826     raise OpenAIError(
#     827         "Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable."
#     828     )
#     830 if organization is None and provider_runtime is None:
#     831     organization = os.environ.get("OPENAI_ORG_ID")
#
# OpenAIError: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.
# OPENAI_API_KEY is not set, skipping trace export

# %%
import os
from dotenv import load_dotenv
from openai import AsyncOpenAI

from agents import (
    Agent,
    Runner,
    OpenAIChatCompletionsModel,
)

load_dotenv()

client = AsyncOpenAI(
    api_key=os.getenv("GEMINI_API_KEY"),
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/",
)

agent = Agent(
    name="Research Planner",
    instructions=instructions,
    model=OpenAIChatCompletionsModel(
        model="gemini-2.5-flash",
        openai_client=client,
    ),
)

result = await Runner.run(
    agent,
    input="learn about AI agents",
)

print(result.final_output)
# Out:
# OPENAI_API_KEY is not set, skipping trace export
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[5], line 27
#      23         openai_client=client,
#      24     ),
#      25 )
#      26
# ---> 27 result = await Runner.run(
#      28     agent,
#      29     input="learn about AI agents",
#      30 )
#
# File c:\Users\user\Documents\LLMs\AI-Agent-Workflows\.venv\Lib\site-packages\agents\run.py:269, in Runner.run(cls, starting_agent, input, context, max_turns, hooks, run_config, error_handlers, previous_response_id, auto_previous_response_id, conversation_id, session)
#     215 """
#     216 Run a workflow starting at the given agent.
#     217
#    (...)    265     type of the output.
#     266 """
#     268 runner = DEFAULT_AGENT_RUNNER
# --> 269 return await runner.run(
#     270     starting_agent,
#     271     input,
#     272     context=context,
#     273     max_turns=max_turns,
#     274     hooks=hooks,
#     275     run_config=run_config,
#     276     error_handlers=error_handlers,
#     277     previous_response_id=previous_response_id,
#     278     auto_previous_response_id=auto_previous_response_id,
#     279     conversation_id=conversation_id,
#     280     session=session,
#     281 )
#
# File c:\Users\user\Documents\LLMs\AI-Agent-Workflows\.venv\Lib\site-packages\agents\run.py:1249, in AgentRunner.run(self, starting_agent, input, **kwargs)
#    1247         raise
#    1248 else:
# -> 1249     turn_result = await model_task
#    1251 input_guardrail_results.extend(sequential_results)
#    1252 input_guardrail_results.extend(parallel_results)
#
# File c:\Users\user\Documents\LLMs\AI-Agent-Workflows\.venv\Lib\site-packages\agents\run_internal\run_loop.py:1770, in run_single_turn(bindings, all_tools, original_input, generated_items, hooks, context_wrapper, run_config, should_run_agent_start_hooks, tool_use_tracker, server_conversation_tracker, session, session_items_to_rewind, reasoning_item_id_policy, prompt_cache_key_resolver, error_handlers)
#    1767 else:
#    1768     input = _prepare_turn_input_items(original_input, generated_items, reasoning_item_id_policy)
# -> 1770 new_response = await get_new_response(
#    1771     bindings,
#    1772     system_prompt,
#    1773     input,
#    1774     output_schema,
#    1775     all_tools,
#    1776     handoffs,
#    1777     hooks,
#    1778     context_wrapper,
#    1779     run_config,
#    1780     tool_use_tracker,
#    1781     server_conversation_tracker,
#    1782     prompt_config,
#    1783     session=session,
#    1784     session_items_to_rewind=session_items_to_rewind,
#    1785     prompt_cache_key_resolver=prompt_cache_key_resolver,
#    1786 )
#    1788 return await get_single_step_result_from_response(
#    1789     bindings=bindings,
#    1790     original_input=original_input,
#    (...)   1801     server_manages_conversation=server_conversation_tracker is not None,
#    1802 )
#
# File c:\Users\user\Documents\LLMs\AI-Agent-Workflows\.venv\Lib\site-packages\agents\run_internal\run_loop.py:1891, in get_new_response(bindings, system_prompt, input, output_schema, all_tools, handoffs, hooks, context_wrapper, run_config, tool_use_tracker, server_conversation_tracker, prompt_config, session, session_items_to_rewind, prompt_cache_key_resolver)
#    1888         server_conversation_tracker.rewind_input(filtered.input)
#    1890 with model_run_context(tool_use_tracker):
# -> 1891     new_response = await get_response_with_retry(
#    1892         get_response=lambda: model.get_response(
#    1893             system_instructions=filtered.instructions,
#    1894             input=filtered.input,
#    1895             model_settings=model_settings,
#    1896             tools=all_tools,
#    1897             output_schema=output_schema,
#    1898             handoffs=handoffs,
#    1899             tracing=get_model_tracing_impl(
#    1900                 run_config.tracing_disabled, run_config.trace_include_sensitive_data
#    1901             ),
#    1902             previous_response_id=previous_response_id,
#    1903             conversation_id=conversation_id,
#    1904             prompt=prompt_config,
#    1905         ),
#    1906         rewind=rewind_model_request,
#    1907         retry_settings=model_settings.retry,
#    1908         get_retry_advice=model.get_retry_advice,
#    1909         previous_response_id=previous_response_id,
#    1910         conversation_id=conversation_id,
#    1911     )
#    1912 if server_conversation_tracker is not None:
#    1913     # Retry helpers rewind sent-input tracking before replaying a failed request. Mark the
#    1914     # filtered input as delivered again once a retry succeeds so subsequent turns only send
#    1915     # new deltas.
#    1916     server_conversation_tracker.mark_input_as_sent(filtered.input)
#
# File c:\Users\user\Documents\LLMs\AI-Agent-Workflows\.venv\Lib\site-packages\agents\run_internal\model_retry.py:439, in get_response_with_retry(get_response, rewind, retry_settings, get_retry_advice, previous_response_id, conversation_id)
#     426 try:
#     427     # Keep provider retries on the initial attempt, but disable them on explicit
#     428     # no-retry settings and on any replay attempt that the runner manages itself.
#     429     with (
#     430         provider_managed_retries_disabled(
#     431             _should_disable_provider_managed_retries(
#    (...)    437         websocket_pre_event_retries_disabled(disable_websocket_pre_event_retry),
#     438     ):
# --> 439         response = await get_response()
#     440     response.usage = apply_retry_attempt_usage(
#     441         response.usage,
#     442         failed_policy_attempts + compatibility_retries_taken,
#     443     )
#     444     return response
#
# File c:\Users\user\Documents\LLMs\AI-Agent-Workflows\.venv\Lib\site-packages\agents\models\openai_chatcompletions.py:212, in OpenAIChatCompletionsModel.get_response(self, system_instructions, input, model_settings, tools, output_schema, handoffs, tracing, previous_response_id, conversation_id, prompt)
#     205 self._handle_unsupported_prompt(prompt)
#     207 with generation_span(
#     208     model=str(self.model),
#     209     model_config=model_config_for_trace(model_settings, base_url=self._client.base_url),
#     210     disabled=tracing.is_disabled(),
#     211 ) as span_generation:
# --> 212     response = await self._fetch_response(
#     213         system_instructions,
#     214         input,
#     215         model_settings,
#     216         tools,
#     217         output_schema,
#     218         handoffs,
#     219         span_generation,
#     220         tracing,
#     221         stream=False,
#     222         prompt=None,
#     223     )
#     225     if not response.choices:
#     226         provider_error = getattr(response, "error", None)
#
# File c:\Users\user\Documents\LLMs\AI-Agent-Workflows\.venv\Lib\site-packages\agents\models\openai_chatcompletions.py:615, in OpenAIChatCompletionsModel._fetch_response(self, system_instructions, input, model_settings, tools, output_schema, handoffs, span, tracing, stream, prompt)
#     610     raise TypeError(
#     611         f"chat.completions.create() got multiple values for keyword arguments {keys}"
#     612     )
#     613 create_kwargs.update(model_settings.extra_args or {})
# --> 615 ret = await self._get_client().chat.completions.create(**create_kwargs)
#     617 if isinstance(ret, ChatCompletion):
#     618     return ret
#
# File c:\Users\user\Documents\LLMs\AI-Agent-Workflows\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:2877, in AsyncCompletions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    2828 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    2829 async def create(
#    2830     self,
#    (...)   2874     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    2875 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
#    2876     validate_response_format(response_format)
# -> 2877     return await self._post(
#    2878         "/chat/completions",
#    2879         body=await async_maybe_transform(
#    2880             {
#    2881                 "messages": messages,
#    2882                 "model": model,
#    2883                 "audio": audio,
#    2884                 "frequency_penalty": frequency_penalty,
#    2885                 "function_call": function_call,
#    2886                 "functions": functions,
#    2887                 "logit_bias": logit_bias,
#    2888                 "logprobs": logprobs,
#    2889                 "max_completion_tokens": max_completion_tokens,
#    2890                 "max_tokens": max_tokens,
#    2891                 "metadata": metadata,
#    2892                 "modalities": modalities,
#    2893                 "moderation": moderation,
#    2894                 "n": n,
#    2895                 "parallel_tool_calls": parallel_tool_calls,
#    2896                 "prediction": prediction,
#    2897                 "presence_penalty": presence_penalty,
#    2898                 "prompt_cache_key": prompt_cache_key,
#    2899                 "prompt_cache_options": prompt_cache_options,
#    2900                 "prompt_cache_retention": prompt_cache_retention,
#    2901                 "reasoning_effort": reasoning_effort,
#    2902                 "response_format": response_format,
#    2903                 "safety_identifier": safety_identifier,
#    2904                 "seed": seed,
#    2905                 "service_tier": service_tier,
#    2906                 "stop": stop,
#    2907                 "store": store,
#    2908                 "stream": stream,
#    2909                 "stream_options": stream_options,
#    2910                 "temperature": temperature,
#    2911                 "tool_choice": tool_choice,
#    2912                 "tools": tools,
#    2913                 "top_logprobs": top_logprobs,
#    2914                 "top_p": top_p,
#    2915                 "user": user,
#    2916                 "verbosity": verbosity,
#    2917                 "web_search_options": web_search_options,
#    2918             },
#    2919             completion_create_params.CompletionCreateParamsStreaming
#    2920             if stream
#    2921             else completion_create_params.CompletionCreateParamsNonStreaming,
#    2922         ),
#    2923         options=make_request_options(
#    2924             extra_headers=extra_headers,
#    2925             extra_query=extra_query,
#    2926             extra_body=extra_body,
#    2927             timeout=timeout,
#    2928             security={"bearer_auth": True},
#    2929         ),
#    2930         cast_to=ChatCompletion,
#    2931         stream=stream or False,
#    2932         stream_cls=AsyncStream[ChatCompletionChunk],
#    2933     )
#
# File c:\Users\user\Documents\LLMs\AI-Agent-Workflows\.venv\Lib\site-packages\openai\_base_client.py:1931, in AsyncAPIClient.post(self, path, cast_to, body, content, files, options, stream, stream_cls)
#    1922     warnings.warn(
#    1923         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1924         "Please pass raw bytes via the `content` parameter instead.",
#    1925         DeprecationWarning,
#    1926         stacklevel=2,
#    1927     )
#    1928 opts = FinalRequestOptions.construct(
#    1929     method="post", url=path, json_data=body, content=content, files=await async_to_httpx_files(files), **options
#    1930 )
# -> 1931 return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File c:\Users\user\Documents\LLMs\AI-Agent-Workflows\.venv\Lib\site-packages\openai\_base_client.py:1716, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1713             await err.response.aread()
#    1715         log.debug("Re-raising status error")
# -> 1716         raise self._make_status_error_from_response(err.response) from None
#    1718     break
#    1720 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - [{'error': {'code': 400, 'message': 'Please pass a valid API key', 'status': 'INVALID_ARGUMENT'}}]
